# %% [markdown]
# # Chapter 4 - Practical Data Visualization
# ## Segment 1 - Creating standard data graphics

# %% [markdown]
# Four steps to choosing data grafics
# 1. Make a list of the questions that your data visualization is meant to answer.
# 2. Is your data visualization type data storytelling, data showcasting, or data art?
# 3. What data graphic types are preferable for that type of data visualization?
# 4. Test out different types of data graphics with your data. Which graphic type displays the most clear and
# obvious answers to your questions?

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ### Creating a line chart from a list object

# %% [markdown]
# #### Plotting a line chart in matplotlib

# %%
x = range(1, 10)
y = [1,2,3,4,0,4,3,2,1]

plt.plot(x, y)

# %% [markdown]
# #### Plotting a line chart from a Pandas object

# %%
address = '../Data/mtcars.csv'

cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

mpg = cars['mpg']

# %%
mpg.plot()

# %%
df = cars[['cyl', 'wt', 'mpg']]
df.plot()

# %% [markdown]
# ### Creating bar charts
# #### Creating a bar chart from a list

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### Creating bar charts from Pandas objects

# %%
mpg.plot(kind='bar')

# %%
mpg.plot(kind='barh')

# %% [markdown]
# ### Creating a pie chart

# %%
x = [1,2,3,10,0.5]
plt.pie(x)
plt.savefig('piechar.png')
plt.show()

# %% [markdown]
# ### Saving a plot

# %%
# Savefig and then plot to save figure
